# %% [markdown]
# # BME1510 Assignment 2: Data Visualization with Iris Dataset
#
# Load the dataset "iris". Answer the following questions using visualizations only:
#
# 1. What is the median petal length for each iris species?
# 2. What is the mean sepal width for each iris species?
# 3. Is there an association between sepal length and width?
# 4. Compare the distributions of petal width for each species.
# 5. Are there any petal length outliers?
# 6. Does the association between pedal and sepal width change with pedal length?

# %%
# !pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (6.25.0)
# Requirement already satisfied: appnope in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from ipykernel) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from ipykernel) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from ipykernel) (9.4.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging in /Users/maleksibai/.local/lib/python3.11/site-packages (from ipykernel) (24.2)
# Requirement already satisfied: psutil in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from ipykernel) (7.1.0)
# Requirement already satisfied: pyzmq>=20 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.1 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from ipykernel) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: decorator in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (4.15.0)
# Requirement already satisfied: wcwidth in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from jupyter-client>=6.1.12->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.3.6)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install seaborn
# !pip install matplotlib
# !pip install pandas
# !pip install numpy
# !pip install scipy
# !pip install scikit-learn
# !pip install scikit-learn
# Out:
# Requirement already satisfied: seaborn in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: pandas>=0.25 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/maleksibai/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from pandas>=0.25->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from pandas>=0.25->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: matplotlib in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.20 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /Users/maleksibai/.local/lib/python3.11/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pandas in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.23.2 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: numpy in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (2.2.6)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: scipy in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from scipy) (2.2.6)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: scikit-learn in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.8.0 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from scikit-learn) (3.5.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: scikit-learn in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.8.0 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/maleksibai/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from scikit-learn) (3.5.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Set seaborn theme for better-looking plots
sns.set_theme(context='notebook', style='darkgrid', palette='deep')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Import libraries
# ----> 2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
#       4 import pandas as pd
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# Load the iris dataset
iris = sns.load_dataset('iris')

# Display first few rows to understand the data
iris.head()

# %% [markdown]
# ## Question 1: What is the median petal length for each iris species?

# %%
# Box plot shows the median (middle line in the box)
plt.figure(figsize=(8, 6))
sns.boxplot(data=iris, x='species', y='petal_length')
plt.xlabel('Species')
plt.ylabel('Petal Length (cm)')
plt.title('Median Petal Length by Species')
plt.show()

# %% [markdown]
# ## Question 2: What is the mean sepal width for each iris species?

# %%
# Bar plot shows the mean (height of bar)
plt.figure(figsize=(8, 6))
sns.barplot(data=iris, x='species', y='sepal_width', estimator='mean')
plt.xlabel('Species')
plt.ylabel('Sepal Width (cm)')
plt.title('Mean Sepal Width by Species')
plt.show()

# %% [markdown]
# ## Question 3: Is there an association between sepal length and width?

# %%
# Scatter plot to visualize association between two variables
plt.figure(figsize=(8, 6))
sns.scatterplot(data=iris, x='sepal_length', y='sepal_width', hue='species')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('Association Between Sepal Length and Width')
plt.legend(title='Species')
plt.show()

# %% [markdown]
# ## Question 4: Compare the distributions of petal width for each species.

# %%
# Violin plot shows the distribution of data
plt.figure(figsize=(8, 6))
sns.violinplot(data=iris, x='species', y='petal_width')
plt.xlabel('Species')
plt.ylabel('Petal Width (cm)')
plt.title('Distribution of Petal Width by Species')
plt.show()

# %% [markdown]
# ## Question 5: Are there any petal length outliers?

# %%
# Box plot shows outliers as individual points beyond the whiskers
plt.figure(figsize=(8, 6))
sns.boxplot(data=iris, x='species', y='petal_length')
plt.xlabel('Species')
plt.ylabel('Petal Length (cm)')
plt.title('Petal Length Outliers by Species')
plt.show()

# %% [markdown]
# ## Question 6: Does the association between petal and sepal width change with petal length?

# %%
# Scatter plot with color coding for petal length
plt.figure(figsize=(10, 6))
scatter = sns.scatterplot(data=iris, x='petal_width', y='sepal_width', 
                          hue='petal_length', size='petal_length', 
                          sizes=(20, 200), palette='viridis')
plt.xlabel('Petal Width (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('Association Between Petal and Sepal Width (colored by Petal Length)')
plt.legend(title='Petal Length', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
